# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/'Colab Notebooks'/G01373042
# Out:
# /content/drive/MyDrive/Colab Notebooks/G01373042

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/G01373042'

# %%
# !pip install torch torchvision torchaudio
# !pip install tqdm==4.58.0
# !pip install requests==2.25.1
# !pip install importlib-metadata==3.7.0
# !pip install filelock==3.0.12
# !pip install sklearn==0.0
# !pip install tokenizers==0.10.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 KB 8.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
# ...

# %%
# %%bash
# python3 classifier.py --option pretrain --train data/sst-train.txt --dev data/sst-dev.txt --test data/sst-test.txt --use_gpu --dev_out sst-dev-output.pretrain_1.txt --test_out sst-test-output.pretrain_1.txt
# Out:
# args: {'train': 'data/sst-train.txt', 'dev': 'data/sst-dev.txt', 'test': 'data/sst-test.txt', 'seed': 11711, 'epochs': 10, 'option': 'pretrain', 'use_gpu': True, 'dev_out': 'sst-dev-output.pretrain_1.txt', 'test_out': 'sst-test-output.pretrain_1.txt', 'batch_size': 8, 'hidden_dropout_prob': 0.3, 'lr': 1e-05}
# load 8544 data from data/sst-train.txt
# load 1101 data from data/sst-dev.txt
# save the model to pretrain-10-1e-05.pt
# epoch 0: train loss :: 2.077, train acc :: 0.311, dev acc :: 0.297
# epoch 1: train loss :: 1.572, train acc :: 0.267, dev acc :: 0.266
# epoch 2: train loss :: 1.559, train acc :: 0.289, dev acc :: 0.294
# save the model to pretrain-10-1e-05.pt
# epoch 3: train loss :: 1.546, train acc :: 0.352, dev acc :: 0.364
# epoch 4: train loss :: 1.535, train acc :: 0.290, dev acc :: 0.295
# epoch 5: train loss :: 1.524, train acc :: 0.371, dev acc :: 0.363
# epoch 6: train loss :: 1.515, train acc :: 0.370, dev acc :: 0.353
# ...

# %%
# %%bash
# python3 classifier.py --option finetune --epochs 10 --lr 0.00001 --train data/sst-train.txt --dev data/sst-dev.txt --test data/sst-test.txt --use_gpu --dev_out sst-dev-output.finetune_1.txt --test_out sst-test-output.finetune_1.txt
# Out:
# args: {'train': 'data/sst-train.txt', 'dev': 'data/sst-dev.txt', 'test': 'data/sst-test.txt', 'seed': 11711, 'epochs': 10, 'option': 'finetune', 'use_gpu': True, 'dev_out': 'sst-dev-output.finetune_1.txt', 'test_out': 'sst-test-output.finetune_1.txt', 'batch_size': 8, 'hidden_dropout_prob': 0.3, 'lr': 1e-05}
# load 8544 data from data/sst-train.txt
# load 1101 data from data/sst-dev.txt
# save the model to finetune-10-1e-05.pt
# epoch 0: train loss :: 1.754, train acc :: 0.542, dev acc :: 0.485
# save the model to finetune-10-1e-05.pt
# epoch 1: train loss :: 1.053, train acc :: 0.668, dev acc :: 0.504
# epoch 2: train loss :: 0.819, train acc :: 0.817, dev acc :: 0.490
# epoch 3: train loss :: 0.620, train acc :: 0.849, dev acc :: 0.495
# epoch 4: train loss :: 0.455, train acc :: 0.892, dev acc :: 0.486
# save the model to finetune-10-1e-05.pt
# epoch 5: train loss :: 0.312, train acc :: 0.918, dev acc :: 0.510
# epoch 6: train loss :: 0.241, train acc :: 0.953, dev acc :: 0.495
# ...

# %%
# %%bash
# python3 classifier.py --option pretrain --train data/cfimdb-train.txt --dev data/cfimdb-dev.txt --test data/cfimdb-test.txt --use_gpu --dev_out cfimdb-dev-output.pretrain_1.txt --test_out cfimdb-test-output.pretrain_1.txt
# Out:
# args: {'train': 'data/cfimdb-train.txt', 'dev': 'data/cfimdb-dev.txt', 'test': 'data/cfimdb-test.txt', 'seed': 11711, 'epochs': 10, 'option': 'pretrain', 'use_gpu': True, 'dev_out': 'cfimdb-dev-output.pretrain_1.txt', 'test_out': 'cfimdb-test-output.pretrain_1.txt', 'batch_size': 8, 'hidden_dropout_prob': 0.3, 'lr': 1e-05}
# load 1707 data from data/cfimdb-train.txt
# load 245 data from data/cfimdb-dev.txt
# save the model to pretrain-10-1e-05.pt
# epoch 0: train loss :: 2.720, train acc :: 0.500, dev acc :: 0.494
# save the model to pretrain-10-1e-05.pt
# epoch 1: train loss :: 0.764, train acc :: 0.584, dev acc :: 0.576
# save the model to pretrain-10-1e-05.pt
# epoch 2: train loss :: 0.728, train acc :: 0.571, dev acc :: 0.612
# save the model to pretrain-10-1e-05.pt
# epoch 3: train loss :: 0.720, train acc :: 0.582, dev acc :: 0.616
# epoch 4: train loss :: 0.693, train acc :: 0.569, dev acc :: 0.551
# epoch 5: train loss :: 0.703, train acc :: 0.514, dev acc :: 0.527
# ...

# %%
# %%bash
# python3 classifier.py --option finetune --train data/cfimdb-train.txt --dev data/cfimdb-dev.txt --test data/cfimdb-test.txt --use_gpu --dev_out cfimdb-dev-output.finetune_1.txt --test_out cfimdb-test-output.finetune_1.txt
# Out:
# args: {'train': 'data/cfimdb-train.txt', 'dev': 'data/cfimdb-dev.txt', 'test': 'data/cfimdb-test.txt', 'seed': 11711, 'epochs': 10, 'option': 'finetune', 'use_gpu': True, 'dev_out': 'cfimdb-dev-output.finetune_1.txt', 'test_out': 'cfimdb-test-output.finetune_1.txt', 'batch_size': 8, 'hidden_dropout_prob': 0.3, 'lr': 1e-05}
# load 1707 data from data/cfimdb-train.txt
# load 245 data from data/cfimdb-dev.txt
# save the model to finetune-10-1e-05.pt
# epoch 0: train loss :: 1.830, train acc :: 0.957, dev acc :: 0.935
# save the model to finetune-10-1e-05.pt
# epoch 1: train loss :: 0.214, train acc :: 0.991, dev acc :: 0.955
# epoch 2: train loss :: 0.061, train acc :: 0.995, dev acc :: 0.955
# save the model to finetune-10-1e-05.pt
# epoch 3: train loss :: 0.046, train acc :: 0.998, dev acc :: 0.963
# epoch 4: train loss :: 0.022, train acc :: 0.999, dev acc :: 0.959
# epoch 5: train loss :: 0.010, train acc :: 0.999, dev acc :: 0.959
# ...
